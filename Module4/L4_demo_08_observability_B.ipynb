# %%
# !pip install tavily-python
# Out:
# Collecting tavily-python
#   Downloading tavily_python-0.7.15-py3-none-any.whl (18 kB)
# Requirement already satisfied: tiktoken>=0.5.1 in /opt/venv/lib/python3.10/site-packages (from tavily-python) (0.8.0)
# Requirement already satisfied: requests in /opt/venv/lib/python3.10/site-packages (from tavily-python) (2.32.3)
# Requirement already satisfied: httpx in /opt/venv/lib/python3.10/site-packages (from tavily-python) (0.28.1)
# Requirement already satisfied: regex>=2022.1.18 in /opt/venv/lib/python3.10/site-packages (from tiktoken>=0.5.1->tavily-python) (2024.11.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/venv/lib/python3.10/site-packages (from requests->tavily-python) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /opt/venv/lib/python3.10/site-packages (from requests->tavily-python) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/venv/lib/python3.10/site-packages (from requests->tavily-python) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/venv/lib/python3.10/site-packages (from requests->tavily-python) (2025.1.31)
# Requirement already satisfied: anyio in /opt/venv/lib/python3.10/site-packages (from httpx->tavily-python) (4.8.0)
# Requirement already satisfied: httpcore==1.* in /opt/venv/lib/python3.10/site-packages (from httpx->tavily-python) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in /opt/venv/lib/python3.10/site-packages (from httpcore==1.*->httpx->tavily-python) (0.14.0)
# Requirement already satisfied: sniffio>=1.1 in /opt/venv/lib/python3.10/site-packages (from anyio->httpx->tavily-python) (1.3.1)
# Requirement already satisfied: typing_extensions>=4.5 in /opt/venv/lib/python3.10/site-packages (from anyio->httpx->tavily-python) (4.12.2)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /opt/venv/lib/python3.10/site-packages (from anyio->httpx->tavily-python) (1.2.2)
# Installing collected packages: tavily-python
# Successfully installed tavily-python-0.7.15
#
# [notice] A new release of pip is available: 23.0.1 -> 25.3
# [notice] To update, run: pip install --upgrade pip

# %%
# !pip install mlflow
# Out:
# Collecting mlflow
#   Downloading mlflow-3.7.0-py3-none-any.whl (8.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.9/8.9 MB 59.0 MB/s eta 0:00:0000:0100:01
# Collecting pandas<3
#   Downloading pandas-2.3.3-cp310-cp310-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (12.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 64.9 MB/s eta 0:00:0000:0100:01
# Collecting pyarrow<23,>=4.0.0
#   Downloading pyarrow-22.0.0-cp310-cp310-manylinux_2_28_x86_64.whl (47.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.6/47.6 MB 28.4 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: sqlalchemy<3,>=1.4.0 in /opt/venv/lib/python3.10/site-packages (from mlflow) (2.0.38)
# Collecting alembic!=1.10.0,<2
#   Downloading alembic-1.17.2-py3-none-any.whl (248 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 248.6/248.6 kB 32.3 MB/s eta 0:00:00
# Collecting Flask-CORS<7
#   Downloading flask_cors-6.0.2-py3-none-any.whl (13 kB)
# Collecting gunicorn<24
#   Downloading gunicorn-23.0.0-py3-none-any.whl (85 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.0/85.0 kB 13.3 MB/s eta 0:00:00
# Collecting mlflow-skinny==3.7.0
#   Downloading mlflow_skinny-3.7.0-py3-none-any.whl (2.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 52.6 MB/s eta 0:00:0000:01
# Collecting Flask<4
#   Downloading flask-3.1.2-py3-none-any.whl (103 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 103.3/103.3 kB 15.7 MB/s eta 0:00:00
# Collecting docker<8,>=4.0.0
#   Downloading docker-7.1.0-py3-none-any.whl (147 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 147.8/147.8 kB 4.9 MB/s eta 0:00:00
# Collecting graphene<4
#   Downloading graphene-3.4.3-py2.py3-none-any.whl (114 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.9/114.9 kB 1.4 MB/s eta 0:00:0000:01
# Collecting scikit-learn<2
#   Downloading scikit_learn-1.7.2-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (9.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.7/9.7 MB 69.5 MB/s eta 0:00:0000:0100:01
# Collecting cryptography<47,>=43.0.0
#   Downloading cryptography-46.0.3-cp38-abi3-manylinux_2_28_x86_64.whl (4.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 67.4 MB/s eta 0:00:00a 0:00:01
# Collecting mlflow-tracing==3.7.0
#   Downloading mlflow_tracing-3.7.0-py3-none-any.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 45.7 MB/s eta 0:00:00
# Collecting matplotlib<4
#   Downloading matplotlib-3.10.8-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (8.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.7/8.7 MB 60.5 MB/s eta 0:00:0000:0100:01m
# Collecting scipy<2
#   Downloading scipy-1.15.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (37.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 37.7/37.7 MB 36.1 MB/s eta 0:00:0000:0100:01
# Collecting huey<3,>=2.5.0
#   Downloading huey-2.5.5-py3-none-any.whl (76 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.9/76.9 kB 14.6 MB/s eta 0:00:00
# Requirement already satisfied: numpy<3 in /opt/venv/lib/python3.10/site-packages (from mlflow) (1.26.4)
# Collecting opentelemetry-proto<3,>=1.9.0
#   Downloading opentelemetry_proto-1.39.1-py3-none-any.whl (72 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.5/72.5 kB 9.6 MB/s eta 0:00:00
# Collecting sqlparse<1,>=0.4.0
#   Downloading sqlparse-0.5.4-py3-none-any.whl (45 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.9/45.9 kB 9.0 MB/s eta 0:00:00
# Collecting opentelemetry-sdk<3,>=1.9.0
#   Downloading opentelemetry_sdk-1.39.1-py3-none-any.whl (132 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.6/132.6 kB 23.2 MB/s eta 0:00:00
# Collecting databricks-sdk<1,>=0.20.0
#   Downloading databricks_sdk-0.74.0-py3-none-any.whl (764 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 764.2/764.2 kB 61.5 MB/s eta 0:00:00
# Requirement already satisfied: pydantic<3,>=2.0.0 in /opt/venv/lib/python3.10/site-packages (from mlflow-skinny==3.7.0->mlflow) (2.10.6)
# Collecting uvicorn<1
#   Downloading uvicorn-0.38.0-py3-none-any.whl (68 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 68.1/68.1 kB 11.7 MB/s eta 0:00:00
# Collecting fastapi<1
#   Downloading fastapi-0.124.4-py3-none-any.whl (113 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 113.3/113.3 kB 16.2 MB/s eta 0:00:00
# Requirement already satisfied: pyyaml<7,>=5.1 in /opt/venv/lib/python3.10/site-packages (from mlflow-skinny==3.7.0->mlflow) (6.0.2)
# Collecting click<9,>=7.0
#   Downloading click-8.3.1-py3-none-any.whl (108 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 108.3/108.3 kB 19.6 MB/s eta 0:00:00
# Collecting importlib_metadata!=4.7.0,<9,>=3.7.0
#   Downloading importlib_metadata-8.7.0-py3-none-any.whl (27 kB)
# Collecting protobuf<7,>=3.12.0
#   Downloading protobuf-6.33.2-cp39-abi3-manylinux2014_x86_64.whl (323 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 323.3/323.3 kB 24.6 MB/s eta 0:00:00
# Requirement already satisfied: packaging<26 in /opt/venv/lib/python3.10/site-packages (from mlflow-skinny==3.7.0->mlflow) (24.2)
# Collecting gitpython<4,>=3.1.9
#   Downloading gitpython-3.1.45-py3-none-any.whl (208 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 208.2/208.2 kB 33.2 MB/s eta 0:00:00
# Collecting opentelemetry-api<3,>=1.9.0
#   Downloading opentelemetry_api-1.39.1-py3-none-any.whl (66 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.4/66.4 kB 12.6 MB/s eta 0:00:00
# Collecting cloudpickle<4
#   Downloading cloudpickle-3.1.2-py3-none-any.whl (22 kB)
# Requirement already satisfied: requests<3,>=2.17.3 in /opt/venv/lib/python3.10/site-packages (from mlflow-skinny==3.7.0->mlflow) (2.32.3)
# Collecting cachetools<7,>=5.0.0
#   Downloading cachetools-6.2.3-py3-none-any.whl (11 kB)
# Requirement already satisfied: python-dotenv<2,>=0.19.0 in /opt/venv/lib/python3.10/site-packages (from mlflow-skinny==3.7.0->mlflow) (1.0.1)
# Requirement already satisfied: typing-extensions<5,>=4.0.0 in /opt/venv/lib/python3.10/site-packages (from mlflow-skinny==3.7.0->mlflow) (4.12.2)
# Collecting Mako
#   Downloading mako-1.3.10-py3-none-any.whl (78 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.5/78.5 kB 13.7 MB/s eta 0:00:00
# Collecting tomli
#   Downloading tomli-2.3.0-py3-none-any.whl (14 kB)
# Collecting typing-extensions<5,>=4.0.0
#   Downloading typing_extensions-4.15.0-py3-none-any.whl (44 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.6/44.6 kB 7.6 MB/s eta 0:00:00
# Collecting cffi>=2.0.0
#   Downloading cffi-2.0.0-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (216 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 216.5/216.5 kB 31.1 MB/s eta 0:00:00
# Requirement already satisfied: urllib3>=1.26.0 in /opt/venv/lib/python3.10/site-packages (from docker<8,>=4.0.0->mlflow) (2.3.0)
# Collecting itsdangerous>=2.2.0
#   Downloading itsdangerous-2.2.0-py3-none-any.whl (16 kB)
# Collecting werkzeug>=3.1.0
#   Downloading werkzeug-3.1.4-py3-none-any.whl (224 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 225.0/225.0 kB 29.3 MB/s eta 0:00:00
# Collecting blinker>=1.9.0
#   Downloading blinker-1.9.0-py3-none-any.whl (8.5 kB)
# Requirement already satisfied: jinja2>=3.1.2 in /opt/venv/lib/python3.10/site-packages (from Flask<4->mlflow) (3.1.5)
# Requirement already satisfied: markupsafe>=2.1.1 in /opt/venv/lib/python3.10/site-packages (from Flask<4->mlflow) (3.0.2)
# Collecting graphql-relay<3.3,>=3.1
#   Downloading graphql_relay-3.2.0-py3-none-any.whl (16 kB)
# Collecting graphql-core<3.3,>=3.1
#   Downloading graphql_core-3.2.7-py3-none-any.whl (207 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.3/207.3 kB 25.9 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil<3,>=2.7.0 in /opt/venv/lib/python3.10/site-packages (from graphene<4->mlflow) (2.9.0.post0)
# Collecting kiwisolver>=1.3.1
#   Downloading kiwisolver-1.4.9-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 58.2 MB/s eta 0:00:00
# Collecting cycler>=0.10
#   Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Collecting fonttools>=4.22.0
#   Downloading fonttools-4.61.1-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (4.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 65.2 MB/s eta 0:00:0000:01:00:01
# Collecting pyparsing>=3
#   Downloading pyparsing-3.2.5-py3-none-any.whl (113 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 113.9/113.9 kB 18.5 MB/s eta 0:00:00
# Collecting contourpy>=1.0.1
#   Downloading contourpy-1.3.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (325 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 325.0/325.0 kB 32.8 MB/s eta 0:00:00
# Collecting pillow>=8
#   Downloading pillow-12.0.0-cp310-cp310-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (7.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.0/7.0 MB 73.5 MB/s eta 0:00:00:00:0100:01
# Collecting pytz>=2020.1
#   Downloading pytz-2025.2-py2.py3-none-any.whl (509 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 509.2/509.2 kB 42.1 MB/s eta 0:00:00
# Collecting tzdata>=2022.7
#   Downloading tzdata-2025.3-py2.py3-none-any.whl (348 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 348.5/348.5 kB 30.4 MB/s eta 0:00:00
# Collecting threadpoolctl>=3.1.0
#   Downloading threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# Collecting joblib>=1.2.0
#   Downloading joblib-1.5.2-py3-none-any.whl (308 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 308.4/308.4 kB 31.6 MB/s eta 0:00:00
# Requirement already satisfied: greenlet!=0.4.17 in /opt/venv/lib/python3.10/site-packages (from sqlalchemy<3,>=1.4.0->mlflow) (3.1.1)
# Requirement already satisfied: pycparser in /opt/venv/lib/python3.10/site-packages (from cffi>=2.0.0->cryptography<47,>=43.0.0->mlflow) (2.22)
# Collecting google-auth~=2.0
#   Downloading google_auth-2.43.0-py2.py3-none-any.whl (223 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 223.1/223.1 kB 24.0 MB/s eta 0:00:00
# Collecting starlette<0.51.0,>=0.40.0
#   Downloading starlette-0.50.0-py3-none-any.whl (74 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 74.0/74.0 kB 12.0 MB/s eta 0:00:00
# Collecting annotated-doc>=0.0.2
#   Downloading annotated_doc-0.0.4-py3-none-any.whl (5.3 kB)
# Collecting gitdb<5,>=4.0.1
#   Downloading gitdb-4.0.12-py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.8/62.8 kB 11.3 MB/s eta 0:00:00
# Collecting zipp>=3.20
#   Downloading zipp-3.23.0-py3-none-any.whl (10 kB)
# Collecting opentelemetry-semantic-conventions==0.60b1
#   Downloading opentelemetry_semantic_conventions-0.60b1-py3-none-any.whl (219 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 220.0/220.0 kB 30.2 MB/s eta 0:00:00
# Requirement already satisfied: annotated-types>=0.6.0 in /opt/venv/lib/python3.10/site-packages (from pydantic<3,>=2.0.0->mlflow-skinny==3.7.0->mlflow) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /opt/venv/lib/python3.10/site-packages (from pydantic<3,>=2.0.0->mlflow-skinny==3.7.0->mlflow) (2.27.2)
# Requirement already satisfied: six>=1.5 in /opt/venv/lib/python3.10/site-packages (from python-dateutil<3,>=2.7.0->graphene<4->mlflow) (1.17.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/venv/lib/python3.10/site-packages (from requests<3,>=2.17.3->mlflow-skinny==3.7.0->mlflow) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/venv/lib/python3.10/site-packages (from requests<3,>=2.17.3->mlflow-skinny==3.7.0->mlflow) (2025.1.31)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/venv/lib/python3.10/site-packages (from requests<3,>=2.17.3->mlflow-skinny==3.7.0->mlflow) (3.4.1)
# Requirement already satisfied: h11>=0.8 in /opt/venv/lib/python3.10/site-packages (from uvicorn<1->mlflow-skinny==3.7.0->mlflow) (0.14.0)
# Collecting smmap<6,>=3.0.1
#   Downloading smmap-5.0.2-py3-none-any.whl (24 kB)
# Collecting pyasn1-modules>=0.2.1
#   Downloading pyasn1_modules-0.4.2-py3-none-any.whl (181 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 181.3/181.3 kB 27.9 MB/s eta 0:00:00
# Collecting rsa<5,>=3.1.4
#   Downloading rsa-4.9.1-py3-none-any.whl (34 kB)
# Requirement already satisfied: anyio<5,>=3.6.2 in /opt/venv/lib/python3.10/site-packages (from starlette<0.51.0,>=0.40.0->fastapi<1->mlflow-skinny==3.7.0->mlflow) (4.8.0)
# Requirement already satisfied: sniffio>=1.1 in /opt/venv/lib/python3.10/site-packages (from anyio<5,>=3.6.2->starlette<0.51.0,>=0.40.0->fastapi<1->mlflow-skinny==3.7.0->mlflow) (1.3.1)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /opt/venv/lib/python3.10/site-packages (from anyio<5,>=3.6.2->starlette<0.51.0,>=0.40.0->fastapi<1->mlflow-skinny==3.7.0->mlflow) (1.2.2)
# Collecting pyasn1<0.7.0,>=0.6.1
#   Downloading pyasn1-0.6.1-py3-none-any.whl (83 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 83.1/83.1 kB 13.4 MB/s eta 0:00:00
# Installing collected packages: pytz, huey, zipp, werkzeug, tzdata, typing-extensions, tomli, threadpoolctl, sqlparse, smmap, scipy, pyparsing, pyasn1, pyarrow, protobuf, pillow, Mako, kiwisolver, joblib, itsdangerous, gunicorn, graphql-core, fonttools, cycler, contourpy, cloudpickle, click, cffi, cachetools, blinker, annotated-doc, uvicorn, scikit-learn, rsa, pyasn1-modules, pandas, opentelemetry-proto, matplotlib, importlib_metadata, graphql-relay, gitdb, Flask, docker, cryptography, starlette, opentelemetry-api, graphene, google-auth, gitpython, Flask-CORS, alembic, opentelemetry-semantic-conventions, fastapi, databricks-sdk, opentelemetry-sdk, mlflow-tracing, mlflow-skinny, mlflow
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing_extensions 4.12.2
#     Uninstalling typing_extensions-4.12.2:
#       Successfully uninstalled typing_extensions-4.12.2
#   Attempting uninstall: cffi
#     Found existing installation: cffi 1.17.1
#     Uninstalling cffi-1.17.1:
#       Successfully uninstalled cffi-1.17.1
# Successfully installed Flask-3.1.2 Flask-CORS-6.0.2 Mako-1.3.10 alembic-1.17.2 annotated-doc-0.0.4 blinker-1.9.0 cachetools-6.2.3 cffi-2.0.0 click-8.3.1 cloudpickle-3.1.2 contourpy-1.3.2 cryptography-46.0.3 cycler-0.12.1 databricks-sdk-0.74.0 docker-7.1.0 fastapi-0.124.4 fonttools-4.61.1 gitdb-4.0.12 gitpython-3.1.45 google-auth-2.43.0 graphene-3.4.3 graphql-core-3.2.7 graphql-relay-3.2.0 gunicorn-23.0.0 huey-2.5.5 importlib_metadata-8.7.0 itsdangerous-2.2.0 joblib-1.5.2 kiwisolver-1.4.9 matplotlib-3.10.8 mlflow-3.7.0 mlflow-skinny-3.7.0 mlflow-tracing-3.7.0 opentelemetry-api-1.39.1 opentelemetry-proto-1.39.1 opentelemetry-sdk-1.39.1 opentelemetry-semantic-conventions-0.60b1 pandas-2.3.3 pillow-12.0.0 protobuf-6.33.2 pyarrow-22.0.0 pyasn1-0.6.1 pyasn1-modules-0.4.2 pyparsing-3.2.5 pytz-2025.2 rsa-4.9.1 scikit-learn-1.7.2 scipy-1.15.3 smmap-5.0.2 sqlparse-0.5.4 starlette-0.50.0 threadpoolctl-3.6.0 tomli-2.3.0 typing-extensions-4.15.0 tzdata-2025.3 uvicorn-0.38.0 werkzeug-3.1.4 zipp-3.23.0
#
# [notice] A new release of pip is available: 23.0.1 -> 25.3
# [notice] To update, run: pip install --upgrade pip

# %%
import mlflow
import os
from typing import Dict
from tavily import TavilyClient
from langchain_openai import ChatOpenAI
from langchain_core.tools import tool
from langgraph.checkpoint.memory import MemorySaver
from langgraph.graph import MessagesState
from langgraph.graph import START, END, StateGraph
from langgraph.prebuilt import ToolNode
from langchain_core.messages import HumanMessage, SystemMessage
from IPython.display import Image, display

# %%
OPENAI_API_KEY="voc-*"
TAVILY_API_KEY="tav-*"

# %%
# !export DATABRICKS_TOKEN=xxx
# !export DATABRICKS_HOST=https://dbc-b47fafb1-7969.cloud.databricks.com
# !export MLFLOW_TRACKING_URI=databricks
# !export MLFLOW_REGISTRY_URI=databricks-uc
# !export MLFLOW_EXPERIMENT_ID=xxx

# %%
# !mlflow server --host 127.0.0.1 --port 8080
# !mlflow ui
# Out:
# Backend store URI not provided. Using sqlite:///mlflow.db
# Registry store URI not provided. Using backend store URI.
# 2025/12/14 14:33:49 INFO mlflow.store.db.utils: Creating initial MLflow database tables...
# 2025/12/14 14:33:49 INFO mlflow.store.db.utils: Updating database tables
# 2025/12/14 14:33:49 INFO alembic.runtime.migration: Context impl SQLiteImpl.
# 2025/12/14 14:33:49 INFO alembic.runtime.migration: Will assume non-transactional DDL.
# 2025/12/14 14:33:49 INFO alembic.runtime.migration: Context impl SQLiteImpl.
# 2025/12/14 14:33:49 INFO alembic.runtime.migration: Will assume non-transactional DDL.
# 2025/12/14 14:33:49 INFO mlflow.store.db.utils: Creating initial MLflow database tables...
# 2025/12/14 14:33:49 INFO mlflow.store.db.utils: Updating database tables
# 2025/12/14 14:33:49 INFO alembic.runtime.migration: Context impl SQLiteImpl.
# 2025/12/14 14:33:49 INFO alembic.runtime.migration: Will assume non-transactional DDL.
# [MLflow] Security middleware enabled with default settings (localhost-only). To allow connections from other hosts, use --host 0.0.0.0 and configure --allowed-hosts and --cors-allowed-origins.
# INFO:     Uvicorn running on http://127.0.0.1:5000 (Press CTRL+C to quit)
# INFO:     Started parent process [343]
# INFO:     Started server process [348]
# INFO:     Waiting for application startup.
# INFO:     Application startup complete.
# INFO:     Started server process [346]
# INFO:     Waiting for application startup.
# INFO:     Application startup complete.
# INFO:     Started server process [345]
# INFO:     Waiting for application startup.
# INFO:     Application startup complete.
# INFO:     Started server process [347]
# INFO:     Waiting for application startup.
# INFO:     Application startup complete.

# %%
tracking_uri = "http://127.0.0.1:5000"
# mlflow.set_tracking_uri(tracking_uri)
mlflow.set_tracking_uri("udacity")
# mlflow.set_tracking_uri("http://localhost:5000")
# mlflow.set_experiment("LangGraph")

# %%
mlflow.langchain.autolog()

# %%
experiment = mlflow.set_experiment("udacity")
# Out:
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# File /opt/venv/lib/python3.10/site-packages/urllib3/connection.py:198, in HTTPConnection._new_conn(self)
#     197 try:
# --> 198     sock = connection.create_connection(
#     199         (self._dns_host, self.port),
#     200         self.timeout,
#     201         source_address=self.source_address,
#     202         socket_options=self.socket_options,
#     203     )
#     204 except socket.gaierror as e:
#
# File /opt/venv/lib/python3.10/site-packages/urllib3/util/connection.py:85, in create_connection(address, timeout, source_address, socket_options)
#      84 try:
# ---> 85     raise err
#      86 finally:
#      87     # Break explicitly a reference cycle
#
# File /opt/venv/lib/python3.10/site-packages/urllib3/util/connection.py:73, in create_connection(address, timeout, source_address, socket_options)
#      72     sock.bind(source_address)
# ---> 73 sock.connect(sa)
#      74 # Break explicitly a reference cycle
#
# ConnectionRefusedError: [Errno 111] Connection refused
#
# The above exception was the direct cause of the following exception:
#
# NewConnectionError                        Traceback (most recent call last)
# File /opt/venv/lib/python3.10/site-packages/urllib3/connectionpool.py:787, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     786 # Make the request on the HTTPConnection object
# --> 787 response = self._make_request(
#     788     conn,
#     789     method,
#     790     url,
#     791     timeout=timeout_obj,
#     792     body=body,
#     793     headers=headers,
#     794     chunked=chunked,
#     795     retries=retries,
#     796     response_conn=response_conn,
#     797     preload_content=preload_content,
#     798     decode_content=decode_content,
#     799     **response_kw,
#     800 )
#     802 # Everything went great!
#
# File /opt/venv/lib/python3.10/site-packages/urllib3/connectionpool.py:493, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     492 try:
# --> 493     conn.request(
#     494         method,
#     495         url,
#     496         body=body,
#     497         headers=headers,
#     498         chunked=chunked,
#     499         preload_content=preload_content,
#     500         decode_content=decode_content,
#     501         enforce_content_length=enforce_content_length,
#     502     )
#     504 # We are swallowing BrokenPipeError (errno.EPIPE) since the server is
#     505 # legitimately able to close the connection after sending a valid response.
#     506 # With this behaviour, the received response is still readable.
#
# File /opt/venv/lib/python3.10/site-packages/urllib3/connection.py:445, in HTTPConnection.request(self, method, url, body, headers, chunked, preload_content, decode_content, enforce_content_length)
#     444     self.putheader(header, value)
# --> 445 self.endheaders()
#     447 # If we're given a body we start sending that in chunks.
#
# File /usr/local/lib/python3.10/http/client.py:1278, in HTTPConnection.endheaders(self, message_body, encode_chunked)
#    1277     raise CannotSendHeader()
# -> 1278 self._send_output(message_body, encode_chunked=encode_chunked)
#
# File /usr/local/lib/python3.10/http/client.py:1038, in HTTPConnection._send_output(self, message_body, encode_chunked)
#    1037 del self._buffer[:]
# -> 1038 self.send(msg)
#    1040 if message_body is not None:
#    1041
#    1042     # create a consistent interface to message_body
#
# File /usr/local/lib/python3.10/http/client.py:976, in HTTPConnection.send(self, data)
#     975 if self.auto_open:
# --> 976     self.connect()
#     977 else:
#
# File /opt/venv/lib/python3.10/site-packages/urllib3/connection.py:276, in HTTPConnection.connect(self)
#     275 def connect(self) -> None:
# --> 276     self.sock = self._new_conn()
#     277     if self._tunnel_host:
#     278         # If we're tunneling it means we're connected to our proxy.
#
# File /opt/venv/lib/python3.10/site-packages/urllib3/connection.py:213, in HTTPConnection._new_conn(self)
#     212 except OSError as e:
# --> 213     raise NewConnectionError(
#     214         self, f"Failed to establish a new connection: {e}"
#     215     ) from e
#     217 sys.audit("http.client.connect", self, self.host, self.port)
#
# NewConnectionError: <urllib3.connection.HTTPConnection object at 0x7ef119485c30>: Failed to establish a new connection: [Errno 111] Connection refused
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 experiment = mlflow.set_experiment("udacity")
#
# File /opt/venv/lib/python3.10/site-packages/mlflow/tracking/fluent.py:190, in set_experiment(experiment_name, experiment_id)
#     188 with _experiment_lock:
#     189     if experiment_id is None:
# --> 190         experiment = client.get_experiment_by_name(experiment_name)
#     191         if not experiment:
#     192             _logger.info(
#     193                 "Experiment with name '%s' does not exist. Creating a new experiment.",
#     194                 experiment_name,
#     195             )
#
# File /opt/venv/lib/python3.10/site-packages/mlflow/tracking/_tracking_service/client.py:280, in TrackingServiceClient.get_experiment_by_name(self, name)
#     272 def get_experiment_by_name(self, name):
#     273     """
#     274     Args:
#     275         name: The experiment name.
#    (...)
#     278         :py:class:`mlflow.entities.Experiment`
#     279     """
# --> 280     return self.store.get_experiment_by_name(name)
#
# File /opt/venv/lib/python3.10/site-packages/mlflow/store/tracking/rest_store.py:889, in RestStore.get_experiment_by_name(self, experiment_name)
#     887 try:
#     888     req_body = message_to_json(GetExperimentByName(experiment_name=experiment_name))
# --> 889     response_proto = self._call_endpoint(GetExperimentByName, req_body)
#     890     return Experiment.from_proto(response_proto.experiment)
#     891 except MlflowException as e:
#
# File /opt/venv/lib/python3.10/site-packages/mlflow/store/tracking/rest_store.py:208, in RestStore._call_endpoint(self, api, json_body, endpoint, retry_timeout_seconds, response_proto)
#     206     endpoint, method = self._METHOD_TO_INFO[api]
#     207 response_proto = response_proto or api.Response()
# --> 208 return call_endpoint(
#     209     self.get_host_creds(),
#     210     endpoint,
#     211     method,
#     212     json_body,
#     213     response_proto,
#     214     retry_timeout_seconds=retry_timeout_seconds,
#     215 )
#
# File /opt/venv/lib/python3.10/site-packages/mlflow/utils/rest_utils.py:591, in call_endpoint(host_creds, endpoint, method, json_body, response_proto, extra_headers, retry_timeout_seconds)
#     589 if method == "GET":
#     590     call_kwargs["params"] = json_body
# --> 591     response = http_request(**call_kwargs)
#     592 else:
#     593     call_kwargs["json"] = json_body
#
# File /opt/venv/lib/python3.10/site-packages/mlflow/utils/rest_utils.py:236, in http_request(host_creds, endpoint, method, max_retries, backoff_factor, backoff_jitter, extra_headers, retry_codes, timeout, raise_on_status, respect_retry_after_header, retry_timeout_seconds, **kwargs)
#     233     kwargs["auth"] = fetch_auth(host_creds.auth)
#     235 try:
# --> 236     return _get_http_response_with_retries(
#     237         method,
#     238         url,
#     239         max_retries,
#     240         backoff_factor,
#     241         backoff_jitter,
#     242         retry_codes,
#     243         raise_on_status,
#     244         headers=headers,
#     245         verify=host_creds.verify,
#     246         timeout=timeout,
#     247         respect_retry_after_header=respect_retry_after_header,
#     248         **kwargs,
#     249     )
#     250 except requests.exceptions.Timeout as to:
#     251     raise MlflowException(
#     252         f"API request to {url} failed with timeout exception {to}."
#     253         " To increase the timeout, set the environment variable "
#     254         f"{MLFLOW_HTTP_REQUEST_TIMEOUT!s} to a larger value."
#     255     ) from to
#
# File /opt/venv/lib/python3.10/site-packages/mlflow/utils/request_utils.py:237, in _get_http_response_with_retries(method, url, max_retries, backoff_factor, backoff_jitter, retry_codes, raise_on_status, allow_redirects, respect_retry_after_header, **kwargs)
#     234 env_value = os.getenv("MLFLOW_ALLOW_HTTP_REDIRECTS", "true").lower() in ["true", "1"]
#     235 allow_redirects = env_value if allow_redirects is None else allow_redirects
# --> 237 return session.request(method, url, allow_redirects=allow_redirects, **kwargs)
#
# File /opt/venv/lib/python3.10/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File /opt/venv/lib/python3.10/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File /opt/venv/lib/python3.10/site-packages/requests/adapters.py:667, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     664     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     666 try:
# --> 667     resp = conn.urlopen(
#     668         method=request.method,
#     669         url=url,
#     670         body=request.body,
#     671         headers=request.headers,
#     672         redirect=False,
#     673         assert_same_host=False,
#     674         preload_content=False,
#     675         decode_content=False,
#     676         retries=self.max_retries,
#     677         timeout=timeout,
#     678         chunked=chunked,
#     679     )
#     681 except (ProtocolError, OSError) as err:
#     682     raise ConnectionError(err, request=request)
#
# File /opt/venv/lib/python3.10/site-packages/urllib3/connectionpool.py:871, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     866 if not conn:
#     867     # Try again
#     868     log.warning(
#     869         "Retrying (%r) after connection broken by '%r': %s", retries, err, url
#     870     )
# --> 871     return self.urlopen(
#     872         method,
#     873         url,
#     874         body,
#     875         headers,
#     876         retries,
#     877         redirect,
#     878         assert_same_host,
#     879         timeout=timeout,
#     880         pool_timeout=pool_timeout,
#     881         release_conn=release_conn,
#     882         chunked=chunked,
#     883         body_pos=body_pos,
#     884         preload_content=preload_content,
#     885         decode_content=decode_content,
#     886         **response_kw,
#     887     )
#     889 # Handle redirect?
#     890 redirect_location = redirect and response.get_redirect_location()
#
# File /opt/venv/lib/python3.10/site-packages/urllib3/connectionpool.py:844, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     839     new_e = ProtocolError("Connection aborted.", new_e)
#     841 retries = retries.increment(
#     842     method, url, error=new_e, _pool=self, _stacktrace=sys.exc_info()[2]
#     843 )
# --> 844 retries.sleep()
#     846 # Keep track of the error for the retry warning.
#     847 err = e
#
# File /opt/venv/lib/python3.10/site-packages/urllib3/util/retry.py:363, in Retry.sleep(self, response)
#     360     if slept:
#     361         return
# --> 363 self._sleep_backoff()
#
# File /opt/venv/lib/python3.10/site-packages/urllib3/util/retry.py:347, in Retry._sleep_backoff(self)
#     345 if backoff <= 0:
#     346     return
# --> 347 time.sleep(backoff)
#
# KeyboardInterrupt:

# %%
@mlflow.trace
def add(a, b):
    return a + b

# %%
add(1, 2)

# %% [markdown]
# **Logging Traces**

# %%
from dotenv import load_dotenv
load_dotenv()
llm = ChatOpenAI(
    model="gpt-4o-mini",
    temperature=0.0,
    api_key=OPENAI_API_KEY,
)

# %%
@tool
def web_search(question:str)->Dict:
    """
    Return top search results for a given search query
    """
    tavily_client = TavilyClient(
        api_key=TAVILY_API_KEY,
#         api_key=os.getenv("TAVILY_API_KEY"),
    )
    response = tavily_client.search(question)
    return response

# %%
class State(MessagesState):
    question: str
    answer: str

# %%
llm_with_tools = llm.bind_tools([web_search])

# %%
def entry_point(state: State):
    question = state["question"]
    system_message = SystemMessage("You conduct web search to respond to user's questions")
    human_message = HumanMessage(question)
    messages = [system_message, human_message]
    return {"messages": messages}

# %%
def agent(state: State):
    messages = state["messages"]
    ai_message = llm_with_tools.invoke(messages)
    return {"messages": ai_message, "answer": ai_message.content}

# %%
def router(state: MessagesState):
    last_message = state["messages"][-1]
    if last_message.tool_calls:
        return "tools"

    return END

# %%
workflow = StateGraph(State)
workflow.add_node("entry_point", entry_point)
workflow.add_node("agent", agent)
workflow.add_node("tools", ToolNode([web_search]))

workflow.add_edge(START, "entry_point")
workflow.add_edge("entry_point", "agent")
workflow.add_conditional_edges(
    source="agent", 
    path=router, 
    path_map=["tools", END]
)
workflow.add_edge("tools", "agent")

# %%
memory = MemorySaver()
graph = workflow.compile(
    interrupt_before=["tools"], 
    checkpointer=memory
)

# %%
display(
    Image(
        graph.get_graph().draw_mermaid_png()
    )
)

# %%
mlflow.langchain.autolog()

# %%
input_question = {"question": "what's the capital of Brazil?"}
config = {"configurable": {"thread_id": 1}}

# %%
for event in graph.stream(input=input_question, config=config, stream_mode="values"):
    if not event['messages']:
        continue
    event['messages'][-1].pretty_print()

# %%
state = graph.get_state(config=config)

# %%
state.next

# %%
for event in graph.stream(input=None, config=config, stream_mode="values"):
    if not event['messages']:
        continue
    event['messages'][-1].pretty_print()
