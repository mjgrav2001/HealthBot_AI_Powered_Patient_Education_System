# %% [markdown]
# # Exercise - Loan Agent - STARTER

# %% [markdown]
# In this exercise, you’ll build a Loan Agent Workflow using LangGraph, designed to negotiate loan amounts with customers.

# %% [markdown]
# **Challenge**
#
# You’re developing an AI-powered Loan agent.
#
# The workflow should:
#
# - Interpret user queries intelligently.
# - Dynamically calls tools for loan calculation
# - Track negotiation status and terminates gracefully.
# - Route the workflow using intelligent conditional edges.

# %% [markdown]
# Your agent will calculate the maximum amount a customer can request based on their profile. If it exceeds, it will mark the status as lost and will explain the reason to the customer. If it meets, make as won, and notify the customer a human representative will contact them.

# %% [markdown]
# By the end of this exercise, you will have learned:
# - Config
# - Limiting Messages (RemoveMessages and summary)
# - Command (Updating State from a Tool)
# - Checkpoints (with thread_id)

# %% [markdown]
# ## 0. Import the necessary libs

# %%
import re
import uuid
from typing_extensions import Literal, Annotated
from typing import List
from langchain_core.messages import (
    SystemMessage,
    AIMessage,
    HumanMessage,
    ToolMessage,
    RemoveMessage,
    AnyMessage
)
# from langchain_core.tools import tool, InjectedToolCallId
from langchain_core.tools import tool
# from langchain_core.tools import InjectedToolCallId
from langchain_openai import ChatOpenAI
from langgraph.graph import START, END, StateGraph
from langchain_core.runnables import RunnableConfig
from langgraph.graph.message import MessagesState, add_messages
from langgraph.checkpoint.memory import MemorySaver
from langgraph.prebuilt import ToolNode
from langgraph.types import Command
from IPython.display import Image, display

# %% [markdown]
# ## 1. Instantiate Chat Model with your API Key

# %% [markdown]
# To be able to connect with OpenAI, you need to instantiate an ChatOpenAI client passing your OpenAI key.
#
# You can pass the `api_key` argument directly.
# ```python
# llm = ChatOpenAI(
#     model="gpt-4o-mini",
#     temperature=0.0,
#     api_key="voc-",
# )
# ```

# %%
OPENAI_API_KEY = "voc-*"

# %%
llm = ChatOpenAI(
    model="gpt-4o-mini",
    temperature=0.0,
    api_key = OPENAI_API_KEY,
)

# %% [markdown]
# ## 2. Create the State Schema

# %% [markdown]
# Your state should have at least 3 elements:
# - customer query, the user input to start the conversation
# - messages, to keep track of the conversation
# - negotiation status, to determine when to terminate the execution
#
# Feel free to use TypedDict or MessagesState.

# %%
# TODO - State Schema called SessionState
class SessionState(MessagesState):
    customer_query: str # the user input to start the conversation
    messages: Annotated[List[AnyMessage], add_messages] # to keep track of the conversation
    negotiation_status: Literal["won", "lost", "in_progress"] # to determine when to terminate the execution

# %% [markdown]
# ## 3. Define your Entrypoint node

# %% [markdown]
# This node should have the following responsibilities:
# - Access all the configuration (RunnableConfig)
# - Create the SystemMessage to instruct the agent
# - Limit number of messages for each execution using summary and RemoveMessage
# -  Create the HumanMessage based on the customer_query

# %%
# TODO - Define your function to summarize previous messages
def summarize_conversation(messages) -> AIMessage:
    summary_message = HumanMessage(
        content="Create a summary of the conversation above:",
        name="User"
        )
    ai_message = llm.invoke(
        add_messages(
            messages,
            summary_message
        )
        )
    delete_messages = [RemoveMessage(id=m.id) for m in messages[:7]]
    messages = add_messages(ai_message, delete_messages)
    return messages

# %%
# TODO - The entrypoint node
# An initial prompt is already created to help you
def entry_point(state: SessionState, config: RunnableConfig):
    messages = state["messages"]
    customer_name = config.get("configurable", {}).get("customer_name", "customer")
    age = config.get("configurable", {}).get("age", 18)
    income = config.get("configurable", {}).get("income", 1000)
    credit_score = config.get("configurable", {}).get("credit_score", 500)
    if not messages:
        prompt = (
            "You are a Loan Agent analysing a customer loan request.\n"
            "- Understand how much the customer needs.\n"
            "- Calculate the maximum loan amount using one of the provided tools.\n"
            "- If the requested amount exceeds the limit, update the negotiation status to 'lost' with the other tool.\n"
            "- If the requested amount meets the limit, update the negotiation status to 'won' with the other tool.\n"
            "- Update status as 'won' or 'lost' based on the negotiation.\n"
            "Terminate gracefully:\n"
            "  - If status is 'won': Notify that a human representative will contact them.\n"
            "  - If status is 'lost': Thank the customer for their time and explain why the loan was refused.\n\n"
            "Print the details about the customer you're negotiating with:\n"
            f"- customer_name: {customer_name}"
            f"- customer_age: {age}"
            f"- customer_income: {income}"
            f"- customer_credit_score: {credit_score}"
        )
        sys_message = SystemMessage(
            content=prompt,
            name="system",
        )
        messages.append(sys_message)

    print(f"Number of messages {len(messages)}")
    # Filter Messages
    if len(messages)>=7:
        # TODO - use summarize_conversation and RemoveMessage
        messages = summarize_conversation(messages)

    print(state["customer_query"])
    human_message = HumanMessage(
        content=state["customer_query"],
        name=re.sub(r'\s+', '_', customer_name.strip()).lower(),
        id = str(uuid.uuid4())
    )
    messages.append(human_message)

    return {
        "messages": messages,
        "negotiation_status": "in_progress",
    }

# %% [markdown]
# ## 4. Define your tools

# %% [markdown]
# You need to create 2 tools:
# - calculate_max_loan, this is important to check if the amount requested meets the maximum allowed by their profile
# - update_negotiation_status, this will update the schema using Command

# %%
# TODO - Max Loan Tool
@tool
def calculate_max_loan(
        age: Annotated[int, "greater than 17"],
        income: Annotated[int, "greater than 0"],
        credit_score: Annotated[int, "between 0 and 1000"],
    ) -> int:
    """
    Calculate the maximum loan amount based on customer's age, income, and credit score.
    - Age: 25-60 gets the highest eligibility, outside this range reduces eligibility.
    - Income: Multiplied by a factor to determine base amount.
    - Credit Score: High score (700+) increases the amount by 20%.
    """
    # TODO - Your logic here
    maximum_loan = 5.0 * 12.0 * income

    if age in range(25,60):
        eligibility = 1.0
    else:
        eligibility = 0.5

    maximum_loan = maximum_loan*eligibility

    if credit_score >= 700:
        maximum_loan = maximum_loan*1.2

    return maximum_loan

# %%
# from langchain_core.tools import InjectedToolCallId
# from langchain.tools import ToolRuntime

# %%
@tool
def update_negotiation_status(
        status: Literal["won", "lost"],
        tool_call_id: str,
    ):
    """
    Updates the negotiation status of the workflow.
    - 'won': If the customer agrees to the loan terms.
    - 'lost': If the customer declines the loan terms.
    - Returns the updated status.
    """

    return Command(
        update={
            # update the state keys
            "negotiation_status": status,
            # update the message history
            "messages": [
                ToolMessage(
                    content="Successfully updated negotiation_status",
                    tool_call_id=tool_call_id
                )
            ],
        }
    )

# %%
tools = [
    calculate_max_loan,
    update_negotiation_status
]

# %% [markdown]
# ## 5. Create your Loan Agent

# %% [markdown]
# Bind tools to the llm built above and create your agent with this llm.

# %%
# TODO - Bind the tools
llm_with_tools = llm.bind_tools(tools, tool_choice="auto")

# %%
# TODO - Define your loan agent
def loan_agent(state: SessionState):
    response = llm_with_tools.invoke(state["messages"])
    return {"messages": response}

# %% [markdown]
# ## 6. Create your Router function

# %% [markdown]
# If the status is 'won' or 'lost', it should proceed to END. Otherwise, if there's a tool call and it's in progress, it should proceed to the tool node called 'tools'.

# %%
def negotiation_router(state: SessionState):
    print(f"inside router status: {state['negotiation_status']}")
    if state["negotiation_status"] != "in_progress":
        return END

    last_message = state["messages"][-1]
    if last_message.tool_calls:
        return "tools"

    return END

# %% [markdown]
# ## 7. Build, Compile and Visualize your Workflow

# %% [markdown]
# - Instantiate the StateGraph with the SessionState
# - Add all the nodes you created
# - Add your edges:
#     - start -> entry point
#     - entry point -> loan agent
#     - loan agent -> [tools, end]
#     - tools -> end
#
# Make sure you use the router function in the conditional edge.
#
# Also, use MemorySaver to compile your graph

# %%
# TODO - define the workflow and add nodes and edges
workflow = StateGraph(SessionState)

workflow.add_node("tools", ToolNode(tools))

workflow.add_node("entry_point", entry_point)
workflow.add_node("loan_agent", loan_agent)

workflow.add_edge(START, "entry_point")
workflow.add_edge("entry_point", "loan_agent")
workflow.add_conditional_edges(
    source="loan_agent",
    path=negotiation_router,
    path_map=["tools", END]
)
workflow.add_edge("tools", END)

# %%
checkpointer = MemorySaver()
loan_graph = workflow.compile(checkpointer=checkpointer)

display(
    Image(
        loan_graph.get_graph().draw_mermaid_png()
    )
)

# %% [markdown]
# ## 8. Invoke your Graph

# %% [markdown]
# Change the input and config and run execute it

# %%
customer_query = "I want to have $1000000"

# %%
inputs = {
    "customer_query": customer_query,
}

config = {
    "thread_id": 1,
    "customer_name": "Henrique Santana",
    "age": 34,
    "income": 1000,
    "credit_score": 750,
}

# %%
output = loan_graph.invoke(
    input=inputs,
    config=config,
)
# Out:
# Number of messages 1
# I want to have $1000000
# inside router status: in_progress

# %% [markdown]
# ## 9. Inspect it

# %% [markdown]
# After executing, inspect the outputs

# %%
for message in output["messages"]:
    message.pretty_print()
# Out:
# ================================ System Message ================================
# Name: system
#
# You are a Loan Agent analysing a customer loan request.
# - Understand how much the customer needs.
# - Calculate the maximum loan amount using one of the provided tools.
# - If the requested amount exceeds the limit, update the negotiation status to 'lost' with the other tool.
# - If the requested amount meets the limit, update the negotiation status to 'won' with the other tool.
# - Update status as 'won' or 'lost' based on the negotiation.
# Terminate gracefully:
#   - If status is 'won': Notify that a human representative will contact them.
#   - If status is 'lost': Thank the customer for their time and explain why the loan was refused.
#
# Print the details about the customer you're negotiating with:
# - customer_name: Henrique Santana- customer_age: 34- customer_income: 1000- customer_credit_score: 750
# ================================ Human Message =================================
# Name: henrique_santana
#
# I want to have $1000000
# ================================== Ai Message ==================================
# Tool Calls:
#   calculate_max_loan (call_13crnzTheE4mxtSFwbza2GF0)
#  Call ID: call_13crnzTheE4mxtSFwbza2GF0
#   Args:
#     age: 34
#     income: 1000
#     credit_score: 750
#   update_negotiation_status (call_EfqGoFjLpJrSsAq8TUvu0eRl)
#  Call ID: call_EfqGoFjLpJrSsAq8TUvu0eRl
#   Args:
#     status: lost
#     tool_call_id: 1
# ================================= Tool Message =================================
# Name: calculate_max_loan
#
# 72000.0
# ================================= Tool Message =================================
# Name: update_negotiation_status
#
# Command(update={'negotiation_status': 'lost', 'messages': [ToolMessage(content='Successfully updated negotiation_status', tool_call_id='1')]})

# %%
output["negotiation_status"]
# Out:
# 'in_progress'

# %%
state_history = list(
    loan_graph.get_state_history(
        config={
            "configurable":{"thread_id":1}
        }
    )
)

# %%
state_history
# Out:
# [StateSnapshot(values={'messages': [SystemMessage(content="You are a Loan Agent analysing a customer loan request.\n- Understand how much the customer needs.\n- Calculate the maximum loan amount using one of the provided tools.\n- If the requested amount exceeds the limit, update the negotiation status to 'lost' with the other tool.\n- If the requested amount meets the limit, update the negotiation status to 'won' with the other tool.\n- Update status as 'won' or 'lost' based on the negotiation.\nTerminate gracefully:\n  - If status is 'won': Notify that a human representative will contact them.\n  - If status is 'lost': Thank the customer for their time and explain why the loan was refused.\n\nPrint the details about the customer you're negotiating with:\n- customer_name: Henrique Santana- customer_age: 34- customer_income: 1000- customer_credit_score: 750", additional_kwargs={}, response_metadata={}, name='system', id='8b49dbcf-a3fe-4650-a395-eff67aecf17c'), HumanMessage(content='I want to have $1000000', additional_kwargs={}, response_metadata={}, name='henrique_santana', id='0968562f-d4d0-479b-962e-865bbf41d16a'), AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_13crnzTheE4mxtSFwbza2GF0', 'function': {'arguments': '{"age": 34, "income": 1000, "credit_score": 750}', 'name': 'calculate_max_loan'}, 'type': 'function'}, {'id': 'call_EfqGoFjLpJrSsAq8TUvu0eRl', 'function': {'arguments': '{"status": "lost", "tool_call_id": "1"}', 'name': 'update_negotiation_status'}, 'type': 'function'}], 'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 65, 'prompt_tokens': 385, 'total_tokens': 450, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_aa07c96156', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-900ee8de-a6ef-4c17-b7b9-8247b5914f76-0', tool_calls=[{'name': 'calculate_max_loan', 'args': {'age': 34, 'income': 1000, 'credit_score': 750}, 'id': 'call_13crnzTheE4mxtSFwbza2GF0', 'type': 'tool_call'}, {'name': 'update_negotiation_status', 'args': {'status': 'lost', 'tool_call_id': '1'}, 'id': 'call_EfqGoFjLpJrSsAq8TUvu0eRl', 'type': 'tool_call'}], usage_metadata={'input_tokens': 385, 'output_tokens': 65, 'total_tokens': 450, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), ToolMessage(content='72000.0', name='calculate_max_loan', id='c6fc5c75-5d91-4752-afac-f1d2ee6a17e8', tool_call_id='call_13crnzTheE4mxtSFwbza2GF0'), ToolMessage(content="Command(update={'negotiation_status': 'lost', 'messages': [ToolMessage(content='Successfully updated negotiation_status', tool_call_id='1')]})", name='update_negotiation_status', id='a127fedb-ae1e-497a-bd1b-cc82b45e43ba', tool_call_id='call_EfqGoFjLpJrSsAq8TUvu0eRl')], 'customer_query': 'I want to have $1000000', 'negotiation_status': 'in_progress'}, next=(), config={'configurable': {'thread_id': 1, 'checkpoint_ns': '', 'checkpoint_id': '1f0d7bb4-2fb4-610f-8003-a4b46bb8afb1'}}, metadata={'source': 'loop', 'writes': {'tools': {'messages': [ToolMessage(content='72000.0', name='calculate_max_loan', id='c6fc5c75-5d91-4752-afac-f1d2ee6a17e8', tool_call_id='call_13crnzTheE4mxtSFwbza2GF0'), ToolMessage(content="Command(update={'negotiation_status': 'lost', 'messages': [ToolMessage(content='Successfully updated negotiation_status', tool_call_id='1')]})", name='update_negotiation_status', id='a127fedb-ae1e-497a-bd1b-cc82b45e43ba', tool_call_id='call_EfqGoFjLpJrSsAq8TUvu0eRl')]}}, 'thread_id': 1, 'customer_name': 'Henrique Santana', 'age': 34, 'income': 1000, 'credit_score': 750, 'step': 3, 'parents': {}}, created_at='2025-12-13T00:32:53.110365+00:00', parent_config={'configurable': {'thread_id': 1, 'checkpoint_ns': '', 'checkpoint_id': '1f0d7bb4-2faa-620a-8002-fff86c96f7d5'}}, tasks= ...
#  StateSnapshot(values={'messages': [SystemMessage(content="You are a Loan Agent analysing a customer loan request.\n- Understand how much the customer needs.\n- Calculate the maximum loan amount using one of the provided tools.\n- If the requested amount exceeds the limit, update the negotiation status to 'lost' with the other tool.\n- If the requested amount meets the limit, update the negotiation status to 'won' with the other tool.\n- Update status as 'won' or 'lost' based on the negotiation.\nTerminate gracefully:\n  - If status is 'won': Notify that a human representative will contact them.\n  - If status is 'lost': Thank the customer for their time and explain why the loan was refused.\n\nPrint the details about the customer you're negotiating with:\n- customer_name: Henrique Santana- customer_age: 34- customer_income: 1000- customer_credit_score: 750", additional_kwargs={}, response_metadata={}, name='system', id='8b49dbcf-a3fe-4650-a395-eff67aecf17c'), HumanMessage(content='I want to have $1000000', additional_kwargs={}, response_metadata={}, name='henrique_santana', id='0968562f-d4d0-479b-962e-865bbf41d16a'), AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_13crnzTheE4mxtSFwbza2GF0', 'function': {'arguments': '{"age": 34, "income": 1000, "credit_score": 750}', 'name': 'calculate_max_loan'}, 'type': 'function'}, {'id': 'call_EfqGoFjLpJrSsAq8TUvu0eRl', 'function': {'arguments': '{"status": "lost", "tool_call_id": "1"}', 'name': 'update_negotiation_status'}, 'type': 'function'}], 'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 65, 'prompt_tokens': 385, 'total_tokens': 450, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_aa07c96156', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-900ee8de-a6ef-4c17-b7b9-8247b5914f76-0', tool_calls=[{'name': 'calculate_max_loan', 'args': {'age': 34, 'income': 1000, 'credit_score': 750}, 'id': 'call_13crnzTheE4mxtSFwbza2GF0', 'type': 'tool_call'}, {'name': 'update_negotiation_status', 'args': {'status': 'lost', 'tool_call_id': '1'}, 'id': 'call_EfqGoFjLpJrSsAq8TUvu0eRl', 'type': 'tool_call'}], usage_metadata={'input_tokens': 385, 'output_tokens': 65, 'total_tokens': 450, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})], 'customer_query': 'I want to have $1000000', 'negotiation_status': 'in_progress'}, next=('tools',), config={'configurable': {'thread_id': 1, 'checkpoint_ns': '', 'checkpoint_id': '1f0d7bb4-2faa-620a-8002-fff86c96f7d5'}}, metadata={'source': 'loop', 'writes': {'loan_agent': {'messages': AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_13crnzTheE4mxtSFwbza2GF0', 'function': {'arguments': '{"age": 34, "income": 1000, "credit_score": 750}', 'name': 'calculate_max_loan'}, 'type': 'function'}, {'id': 'call_EfqGoFjLpJrSsAq8TUvu0eRl', 'function': {'arguments': '{"status": "lost", "tool_call_id": "1"}', 'name': 'update_negotiation_status'}, 'type': 'function'}], 'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 65, 'prompt_tokens': 385, 'total_tokens': 450, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_aa07c96156', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-900ee8de-a6ef-4c17-b7b9-8247b5914f76-0', tool_calls=[{'name': 'calculate_max_loan', 'args': {'age': 34, 'income': 1000, 'credit_score': 750}, 'id': 'call_13crnzTheE4mxtSFwbza2GF0', 'type': 'tool_call'}, {'name': 'update_negotiation_status', 'args': {'status': 'lost', 'tool_call_id': '1'}, 'id': 'call_EfqGoFjLpJrSsAq ...
#  StateSnapshot(values={'messages': [SystemMessage(content="You are a Loan Agent analysing a customer loan request.\n- Understand how much the customer needs.\n- Calculate the maximum loan amount using one of the provided tools.\n- If the requested amount exceeds the limit, update the negotiation status to 'lost' with the other tool.\n- If the requested amount meets the limit, update the negotiation status to 'won' with the other tool.\n- Update status as 'won' or 'lost' based on the negotiation.\nTerminate gracefully:\n  - If status is 'won': Notify that a human representative will contact them.\n  - If status is 'lost': Thank the customer for their time and explain why the loan was refused.\n\nPrint the details about the customer you're negotiating with:\n- customer_name: Henrique Santana- customer_age: 34- customer_income: 1000- customer_credit_score: 750", additional_kwargs={}, response_metadata={}, name='system', id='8b49dbcf-a3fe-4650-a395-eff67aecf17c'), HumanMessage(content='I want to have $1000000', additional_kwargs={}, response_metadata={}, name='henrique_santana', id='0968562f-d4d0-479b-962e-865bbf41d16a')], 'customer_query': 'I want to have $1000000', 'negotiation_status': 'in_progress'}, next=('loan_agent',), config={'configurable': {'thread_id': 1, 'checkpoint_ns': '', 'checkpoint_id': '1f0d7bb4-1197-6528-8001-9e8d6f1ba4c3'}}, metadata={'source': 'loop', 'writes': {'entry_point': {'messages': [SystemMessage(content="You are a Loan Agent analysing a customer loan request.\n- Understand how much the customer needs.\n- Calculate the maximum loan amount using one of the provided tools.\n- If the requested amount exceeds the limit, update the negotiation status to 'lost' with the other tool.\n- If the requested amount meets the limit, update the negotiation status to 'won' with the other tool.\n- Update status as 'won' or 'lost' based on the negotiation.\nTerminate gracefully:\n  - If status is 'won': Notify that a human representative will contact them.\n  - If status is 'lost': Thank the customer for their time and explain why the loan was refused.\n\nPrint the details about the customer you're negotiating with:\n- customer_name: Henrique Santana- customer_age: 34- customer_income: 1000- customer_credit_score: 750", additional_kwargs={}, response_metadata={}, name='system', id='8b49dbcf-a3fe-4650-a395-eff67aecf17c'), HumanMessage(content='I want to have $1000000', additional_kwargs={}, response_metadata={}, name='henrique_santana', id='0968562f-d4d0-479b-962e-865bbf41d16a')], 'negotiation_status': 'in_progress'}}, 'thread_id': 1, 'customer_name': 'Henrique Santana', 'age': 34, 'income': 1000, 'credit_score': 750, 'step': 1, 'parents': {}}, created_at='2025-12-13T00:32:49.952882+00:00', parent_config={'configurable': {'thread_id': 1, 'checkpoint_ns': '', 'checkpoint_id': '1f0d7bb4-1192-6ac8-8000-457faac66c40'}}, tasks=(PregelTask(id='b4f52c84-dfa3-dd01-754a-ae9dc9357a3f', name='loan_agent', path=('__pregel_pull', 'loan_agent'), error=None, interrupts=(), state=None, result={'messages': AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_13crnzTheE4mxtSFwbza2GF0', 'function': {'arguments': '{"age": 34, "income": 1000, "credit_score": 750}', 'name': 'calculate_max_loan'}, 'type': 'function'}, {'id': 'call_EfqGoFjLpJrSsAq8TUvu0eRl', 'function': {'arguments': '{"status": "lost", "tool_call_id": "1"}', 'name': 'update_negotiation_status'}, 'type': 'function'}], 'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 65, 'prompt_tokens': 385, 'total_tokens': 450, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_aa07c96156', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-900ee8de-a6ef-4c17-b7b9-8247b5914f76-0', tool_calls=[{'name': 'calculate_max_loan', 'args' ...
#  StateSnapshot(values={'messages': [], 'customer_query': 'I want to have $1000000'}, next=('entry_point',), config={'configurable': {'thread_id': 1, 'checkpoint_ns': '', 'checkpoint_id': '1f0d7bb4-1192-6ac8-8000-457faac66c40'}}, metadata={'source': 'loop', 'writes': None, 'thread_id': 1, 'customer_name': 'Henrique Santana', 'age': 34, 'income': 1000, 'credit_score': 750, 'step': 0, 'parents': {}}, created_at='2025-12-13T00:32:49.950980+00:00', parent_config={'configurable': {'thread_id': 1, 'checkpoint_ns': '', 'checkpoint_id': '1f0d7bb4-118e-69ac-bfff-1cfd932f4a36'}}, tasks=(PregelTask(id='62c569c6-dcd6-0a04-73a8-5928150a4624', name='entry_point', path=('__pregel_pull', 'entry_point'), error=None, interrupts=(), state=None, result={'messages': [SystemMessage(content="You are a Loan Agent analysing a customer loan request.\n- Understand how much the customer needs.\n- Calculate the maximum loan amount using one of the provided tools.\n- If the requested amount exceeds the limit, update the negotiation status to 'lost' with the other tool.\n- If the requested amount meets the limit, update the negotiation status to 'won' with the other tool.\n- Update status as 'won' or 'lost' based on the negotiation.\nTerminate gracefully:\n  - If status is 'won': Notify that a human representative will contact them.\n  - If status is 'lost': Thank the customer for their time and explain why the loan was refused.\n\nPrint the details about the customer you're negotiating with:\n- customer_name: Henrique Santana- customer_age: 34- customer_income: 1000- customer_credit_score: 750", additional_kwargs={}, response_metadata={}, name='system', id='8b49dbcf-a3fe-4650-a395-eff67aecf17c'), HumanMessage(content='I want to have $1000000', additional_kwargs={}, response_metadata={}, name='henrique_santana', id='0968562f-d4d0-479b-962e-865bbf41d16a')], 'negotiation_status': 'in_progress'}),)),
#  StateSnapshot(values={'messages': []}, next=('__start__',), config={'configurable': {'thread_id': 1, 'checkpoint_ns': '', 'checkpoint_id': '1f0d7bb4-118e-69ac-bfff-1cfd932f4a36'}}, metadata={'source': 'input', 'writes': {'__start__': {'customer_query': 'I want to have $1000000'}}, 'thread_id': 1, 'customer_name': 'Henrique Santana', 'age': 34, 'income': 1000, 'credit_score': 750, 'step': -1, 'parents': {}}, created_at='2025-12-13T00:32:49.949313+00:00', parent_config=None, tasks=(PregelTask(id='7b101a51-876d-06e9-f822-a3994c540441', name='__start__', path=('__pregel_pull', '__start__'), error=None, interrupts=(), state=None, result={'customer_query': 'I want to have $1000000'}),))]

# %%
state_history[0].values["messages"][-1].content
# Out:
# "Command(update={'negotiation_status': 'lost', 'messages': [ToolMessage(content='Successfully updated negotiation_status', tool_call_id='1')]})"

# %%
for m in state_history[0].values["messages"]:
    m.pretty_print()
# Out:
# ================================ System Message ================================
# Name: system
#
# You are a Loan Agent analysing a customer loan request.
# - Understand how much the customer needs.
# - Calculate the maximum loan amount using one of the provided tools.
# - If the requested amount exceeds the limit, update the negotiation status to 'lost' with the other tool.
# - If the requested amount meets the limit, update the negotiation status to 'won' with the other tool.
# - Update status as 'won' or 'lost' based on the negotiation.
# Terminate gracefully:
#   - If status is 'won': Notify that a human representative will contact them.
#   - If status is 'lost': Thank the customer for their time and explain why the loan was refused.
#
# Print the details about the customer you're negotiating with:
# - customer_name: Henrique Santana- customer_age: 34- customer_income: 1000- customer_credit_score: 750
# ================================ Human Message =================================
# Name: henrique_santana
#
# I want to have $1000000
# ================================== Ai Message ==================================
# Tool Calls:
#   calculate_max_loan (call_13crnzTheE4mxtSFwbza2GF0)
#  Call ID: call_13crnzTheE4mxtSFwbza2GF0
#   Args:
#     age: 34
#     income: 1000
#     credit_score: 750
#   update_negotiation_status (call_EfqGoFjLpJrSsAq8TUvu0eRl)
#  Call ID: call_EfqGoFjLpJrSsAq8TUvu0eRl
#   Args:
#     status: lost
#     tool_call_id: 1
# ================================= Tool Message =================================
# Name: calculate_max_loan
#
# 72000.0
# ================================= Tool Message =================================
# Name: update_negotiation_status
#
# Command(update={'negotiation_status': 'lost', 'messages': [ToolMessage(content='Successfully updated negotiation_status', tool_call_id='1')]})

# %% [markdown]
# ## 10. Experiment

# %% [markdown]
# Now that you understood how it works, experiment with new things.
#
# - Run multiple times for the same thread_id, whant happens with the messages?
# - Add a tool to calculate interests and taxes to enable pay in installments
# - Improve negotiation, allowing the agent to offer discounts to close the deal
