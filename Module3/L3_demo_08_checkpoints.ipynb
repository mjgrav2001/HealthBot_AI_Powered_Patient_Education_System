# %%
from typing import TypedDict, List, Annotated
import operator
from langgraph.checkpoint.memory import MemorySaver
from langgraph.graph import StateGraph, MessagesState, START, END
from IPython.display import Image, display

# %%
class State(TypedDict):
    value: Annotated[List[str], operator.add]

def node_a(state: State):
    return {"value": ["a"]}

def node_b(state: State):
    return {"value": ["b"]}

workflow = StateGraph(State)

workflow.add_node(node_a)
workflow.add_node(node_b)

workflow.add_edge(START, "node_a")
workflow.add_edge("node_a", "node_b")
workflow.add_edge("node_b", END)

graph = workflow.compile()

display(
    Image(
        graph.get_graph().draw_mermaid_png()
    )
)

# %%
graph.invoke({"value":[]})
# Out:
# {'value': ['a', 'b']}

# %% [markdown]
# **Checkpoints**

# %%
checkpointer = MemorySaver()
graph = workflow.compile(checkpointer=checkpointer)

# %%
config = {"configurable": {"thread_id": "1"}}
graph.invoke({"value": []}, config)
# Out:
# {'value': ['a', 'b']}

# %%
config = {"configurable": {"thread_id": "1"}}
graph.invoke({"value": []}, config)
# Out:
# {'value': ['a', 'b', 'a', 'b']}

# %%
config = {"configurable": {"thread_id": "2"}}
graph.invoke({"value": []}, config)
# Out:
# {'value': ['a', 'b']}

# %%
config = {"configurable": {"thread_id": "3"}}
graph.invoke({"value": []}, config)
# Out:
# {'value': ['a', 'b']}

# %%
list(graph.get_state_history({"configurable": {"thread_id": "1"}}))
# Out:
# [StateSnapshot(values={'value': ['a', 'b', 'a', 'b']}, next=(), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0d6d0d-1ba5-686a-8006-c3fb6f9ed761'}}, metadata={'source': 'loop', 'writes': {'node_b': {'value': ['b']}}, 'thread_id': '1', 'step': 6, 'parents': {}}, created_at='2025-12-11T20:34:40.867731+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0d6d0d-1ba3-6320-8005-3e6ece15ffba'}}, tasks=()),
#  StateSnapshot(values={'value': ['a', 'b', 'a']}, next=('node_b',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0d6d0d-1ba3-6320-8005-3e6ece15ffba'}}, metadata={'source': 'loop', 'writes': {'node_a': {'value': ['a']}}, 'thread_id': '1', 'step': 5, 'parents': {}}, created_at='2025-12-11T20:34:40.866778+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0d6d0d-1ba0-6469-8004-7902d6615e30'}}, tasks=(PregelTask(id='cae7ee89-d4e5-3a7c-5498-7476f5a8fa28', name='node_b', path=('__pregel_pull', 'node_b'), error=None, interrupts=(), state=None, result={'value': ['b']}),)),
#  StateSnapshot(values={'value': ['a', 'b']}, next=('node_a',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0d6d0d-1ba0-6469-8004-7902d6615e30'}}, metadata={'source': 'loop', 'writes': None, 'thread_id': '1', 'step': 4, 'parents': {}}, created_at='2025-12-11T20:34:40.865582+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0d6d0d-1b9d-6dac-8003-0c0800d9c27b'}}, tasks=(PregelTask(id='9176c508-d8a6-52aa-0c29-fc369abc16b9', name='node_a', path=('__pregel_pull', 'node_a'), error=None, interrupts=(), state=None, result={'value': ['a']}),)),
#  StateSnapshot(values={'value': ['a', 'b']}, next=('__start__',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0d6d0d-1b9d-6dac-8003-0c0800d9c27b'}}, metadata={'source': 'input', 'writes': {'__start__': {'value': []}}, 'thread_id': '1', 'step': 3, 'parents': {}}, created_at='2025-12-11T20:34:40.864591+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0d6d0d-1b90-6134-8002-8a768d41f3a2'}}, tasks=(PregelTask(id='40233931-502e-1d5f-f0e3-75202da7bb90', name='__start__', path=('__pregel_pull', '__start__'), error=None, interrupts=(), state=None, result={'value': []}),)),
#  StateSnapshot(values={'value': ['a', 'b']}, next=(), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0d6d0d-1b90-6134-8002-8a768d41f3a2'}}, metadata={'source': 'loop', 'writes': {'node_b': {'value': ['b']}}, 'thread_id': '1', 'step': 2, 'parents': {}}, created_at='2025-12-11T20:34:40.858947+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0d6d0d-1b8e-658a-8001-a750efc99a08'}}, tasks=()),
#  StateSnapshot(values={'value': ['a']}, next=('node_b',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0d6d0d-1b8e-658a-8001-a750efc99a08'}}, metadata={'source': 'loop', 'writes': {'node_a': {'value': ['a']}}, 'thread_id': '1', 'step': 1, 'parents': {}}, created_at='2025-12-11T20:34:40.858241+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0d6d0d-1b8c-6da9-8000-110a11a99968'}}, tasks=(PregelTask(id='55dee736-7edf-f872-d9f3-34a5acc58a1b', name='node_b', path=('__pregel_pull', 'node_b'), error=None, interrupts=(), state=None, result={'value': ['b']}),)),
#  StateSnapshot(values={'value': []}, next=('node_a',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0d6d0d-1b8c-6da9-8000-110a11a99968'}}, metadata={'source': 'loop', 'writes': None, 'thread_id': '1', 'step': 0, 'parents': {}}, created_at='2025-12-11T20:34:40.857629+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0d6d0d-1b8a-6ee1-bfff-153b8efc5e87'}}, tasks=(PregelTask(id='05de6730-27c2-b6f7-fc05-f176b2f56174', name='node_a', path=('__pregel_pull', 'node_a'), error=None, interrupts=(), state=None, result={'value': ['a']}),)),
#  StateSnapshot(values={'value': []}, next=('__start__',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0d6d0d-1b8a-6ee1-bfff-153b8efc5e87'}}, metadata={'source': 'input', 'writes': {'__start__': {'value': []}}, 'thread_id': '1', 'step': -1, 'parents': {}}, created_at='2025-12-11T20:34:40.856847+00:00', parent_config=None, tasks=(PregelTask(id='20abe1c0-1f7a-d6b1-472e-4c805b7009b4', name='__start__', path=('__pregel_pull', '__start__'), error=None, interrupts=(), state=None, result={'value': []}),))]

# %%
list(graph.get_state_history({"configurable": {"thread_id": "2"}}))
# Out:
# [StateSnapshot(values={'value': ['a', 'b']}, next=(), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f0d6d0d-1bba-640b-8002-38bad1577a10'}}, metadata={'source': 'loop', 'writes': {'node_b': {'value': ['b']}}, 'thread_id': '2', 'step': 2, 'parents': {}}, created_at='2025-12-11T20:34:40.876223+00:00', parent_config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f0d6d0d-1bb8-6b46-8001-2be95c390f2e'}}, tasks=()),
#  StateSnapshot(values={'value': ['a']}, next=('node_b',), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f0d6d0d-1bb8-6b46-8001-2be95c390f2e'}}, metadata={'source': 'loop', 'writes': {'node_a': {'value': ['a']}}, 'thread_id': '2', 'step': 1, 'parents': {}}, created_at='2025-12-11T20:34:40.875591+00:00', parent_config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f0d6d0d-1bb6-6a34-8000-600d274fe716'}}, tasks=(PregelTask(id='b56c172e-7b86-aa5e-af60-ceaca0aaae4b', name='node_b', path=('__pregel_pull', 'node_b'), error=None, interrupts=(), state=None, result={'value': ['b']}),)),
#  StateSnapshot(values={'value': []}, next=('node_a',), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f0d6d0d-1bb6-6a34-8000-600d274fe716'}}, metadata={'source': 'loop', 'writes': None, 'thread_id': '2', 'step': 0, 'parents': {}}, created_at='2025-12-11T20:34:40.874744+00:00', parent_config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f0d6d0d-1bb4-6b90-bfff-7d245a2a9f61'}}, tasks=(PregelTask(id='6c17660a-7e3e-ec3e-84dc-8051936f0d20', name='node_a', path=('__pregel_pull', 'node_a'), error=None, interrupts=(), state=None, result={'value': ['a']}),)),
#  StateSnapshot(values={'value': []}, next=('__start__',), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f0d6d0d-1bb4-6b90-bfff-7d245a2a9f61'}}, metadata={'source': 'input', 'writes': {'__start__': {'value': []}}, 'thread_id': '2', 'step': -1, 'parents': {}}, created_at='2025-12-11T20:34:40.873965+00:00', parent_config=None, tasks=(PregelTask(id='f6cbd53f-1200-b618-09fd-2e41cba8967c', name='__start__', path=('__pregel_pull', '__start__'), error=None, interrupts=(), state=None, result={'value': []}),))]
